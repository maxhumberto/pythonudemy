# %%
x: int
soma: int

soma = 0
x = int(input("Digite o primeiro nome: "))

while x !=0:
  soma = soma + x
  x = int(input("digite outro numero: "))
print("Soma = ", soma)
# Out:
# Digite o primeiro nome: 1
# digite outro numero2
# digite outro numero4
# digite outro numero5
# digite outro numero0
# Soma =  12
