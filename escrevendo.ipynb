# %%
from google.colab.patches import cv2_imshow
import cv2

imagem = cv2.imread("/content/one-piece-anime-1015-luffy-chapeu-postcover.jpg")

fonte = cv2.FONT_HERSHEY_COMPLEX
cv2.putText(imagem, "Humberto", (100, 100), fonte, 2, (123, 50, 100), 2, cv2. LINE_AA)

cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F89847256A0>
