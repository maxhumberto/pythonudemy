# %%
x = 10
print(x)
# Out:
# 10

# %%
x = [1, 2, 3, 4, 5]
x
x.append(11)
x
# Out:
# [1, 2, 3, 4, 5, 11]

# %%
x.pop()
# Out:
# 5

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
x[:3]
# Out:
# [1, 2, 3]

# %%
x[::-1]
# Out:
# [4, 3, 2, 1]
