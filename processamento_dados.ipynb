# %%
x: int
y: float

x = 5
y = 2 * x
print(x)
print(y)
# Out:
# 5
# 10

# %%
b1: float
b2:float
h: float
area: float
b1 = 6.0
b2 = 8.0
h = 5.0
area = (b1+b2) / 2.0 * h 
print(area)
# Out:
# 35.0

# %%
a: int
b: int
resultado: int

a = 5
b = 2
resultado = a / b
# resultado = a // b para obter resultado inteiro.
print (resultado)
# Out:
# 2.5

# %%
a: float
b: int
a = 5.2
b = int(a) #força a incluir numero inteiro.
print(b)
# Out:
# 5
