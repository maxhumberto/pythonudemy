# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

imagem = cv2.imread("/content/3.jpg")

cv2_imshow(imagem)

recorte = imagem[925:1367, 1220:1500 ]


recorte2= imagem[825:1367 , 1525:1955]

mascara = np.zeros(recorte.shape[:2], dtype="uint8")
(cx, cy)= (recorte.shape[1] //4, recorte.shape[0] // 2)
cv2.circle(mascara, (cx, cy), 82, 255, -1)


cv2_imshow(recorte)
cv2.imwrite("recorte1.jpg", recorte)


cv2_imshow(recorte2)
cv2.imwrite("recorte3.jpg", recorte2)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
