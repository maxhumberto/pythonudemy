# %%
from google.colab.patches import cv2_imshow
import cv2

imagem = cv2.imread("/content/one-piece-anime-1015-luffy-chapeu-postcover.jpg")

(b,g,r) = cv2.split(imagem)



cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7EFF7AA79B20>
