# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

imagem = cv2.imread("/5.jpg")

cv2_imshow(imagem)
print(imagem.shape[0])
print(imagem.shape[1])
print(imagem.shape[2])

recorte = imagem[390:700, 780:1150]

recorte2 = imagem[590:730, 930:1080]

recorte3 = imagem[950:1250,  800:970]

recorte4 = imagem[1180:1370,  1050:1250]

recorte5 = imagem[1120:1280, 1450:1610]

cv2_imshow(recorte)
cv2.imwrite("capacete.jpg", recorte)


cv2_imshow(recorte2)
cv2.imwrite("oculos.jpg", recorte2)

cv2_imshow(recorte3)
cv2.imwrite("radio.jpg", recorte3)

cv2_imshow(recorte4)
cv2.imwrite("mao1.jpg", recorte4)

cv2_imshow(recorte5)
cv2.imwrite("mao2.jpg", recorte5)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
