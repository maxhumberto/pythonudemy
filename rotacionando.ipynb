# %%
from google.colab.patches import cv2_imshow
import cv2

imagem = cv2.imread("/content/a49cf76d5fecb2bad68580a1f699391aab34ba5b.jpg")

imgRotacionada = imagem[:, ::-1]

#imgagem fica de cabeca p baixo
#imgRotacionada = imagem[::-1, :]

cv2_imshow(imgRotacionada)
cv2_imshow(imagem)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
