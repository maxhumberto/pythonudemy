# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

imagem = cv2.imread("/content/1.jpg")

cv2_imshow(imagem)
print(imagem.shape[0])
print(imagem.shape[1])
print(imagem.shape[2])

recorte = imagem[1090:1310, 960:1140]

recorte2 = imagem[1150:1410, 1760:2150]

recorte3 = imagem[1120:1590, 1525:1687]

cv2_imshow(recorte)
cv2.imwrite("recortecarro.jpg", recorte)


cv2_imshow(recorte2)
cv2.imwrite("recortecarro2.jpg", recorte2)

cv2_imshow(recorte3)
cv2.imwrite("recortecarro3.jpg", recorte3)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
