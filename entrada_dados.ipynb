# %%
#leia input() 
#     input("mensagem")
#x = int(input("Digite um numero: "))
#x = float(input("Digite um numero: ")) 

salario1: float
salario2: float
idade: int
sexo: str
nome1:str
nome2:str

nome1 = input("Nome da primeira pessoa: ")
salario1 = float(input("Digite o salario da primeira pessoa: "))

nome2 = input("Nome da segunda pessoa: ")
salario2 = float(input("Digite o salario da segunda pessoa: "))
idade = int(input("Digite uma idade: "))
sexo = input("Digite um sexo (F/M): ")

print(f"nome 1: {nome1}")
print(f"Salario 1: {salario1:.2f}")
print(f"nome 2: {nome2}")
print(f"Salario 2: {salario2:.2f}")
print(f"idade: {idade}")
print(f"sexo: {sexo}")
# Out:
# Nome da primeira pessoa: Humberto
# Digite o salario da primeira pessoa: 5000.00
# Nome da segunda pessoa: Carol
# Digite o salario da segunda pessoa: 3000.00
# Digite uma idade: 30
# Digite um sexo (F/M): m
# nome 1: Humberto
#  Salario 1: 5000.00
# nome 2: Carol
#  Salario 2: 3000.00
# idade: 30
# sexo: m
