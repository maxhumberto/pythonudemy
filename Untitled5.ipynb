# %%
from google.colab import files


import cv2
from google.colab.patches import cv2_imshow

imagem = cv2.imread("tiger.jpg")

for y in range(0, imagem.shape[0], 4):
  for x in range(0, imagem.shape[1], 4):
    imagem[y: y +50, x: x +3] = (255,150, 90)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=900x599 at 0x7FC4FE6C6D60>
