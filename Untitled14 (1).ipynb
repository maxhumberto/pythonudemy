# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

imagem = cv2.imread("/content/one-piece-anime-1015-luffy-chapeu-postcover.jpg")

cv2_imshow(imagem)

img_redimensionada = imagem [::2, ::2]
imgRotacionada = imagem[:, ::-1]
imgeRotacionada = imagem[::-1, :]
cv2_imshow(img_redimensionada)
cv2_imshow(imgRotacionada)
cv2_imshow(imgeRotacionada)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
